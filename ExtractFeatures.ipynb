# %%
#https://librosa.org/doc/main/auto_examples/plot_display.html
import librosa, audioread
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os, cv2, warnings
from pydub import AudioSegment

folders=['Progressive_Rock_Songs','Not_Progressive_Rock/Other_Songs','Not_Progressive_Rock/Top_Of_The_Pops']
saveFolders = ['ExtractDataset/prog/', 'ExtractDataset/nonprog/']

#1 for prog; 0 for nonprog
database = {'idx':[],'ReName':[],'Style':[],'Label':[],'StartDur (Sec)':[],'EndDur (Sec)':[],'Duration (Sec)':[]
            ,'OriName':[], 'DbMax':[],'DbMin':[]}
saveArr = []
saveImgArr = []
saveImgArrLog=[]
labels = []
filesName = []
for folder in folders:
    if folder == 'Progressive_Rock_Songs':
        saveFolder = saveFolders[0]
        reName = 'Prog-'
        style = 'Prog'
        idx = 0
        label = 1

    if folder == 'Not_Progressive_Rock/Other_Songs':
        saveFolder = saveFolders[1]
        reName = 'NonProgOther-'
        style = 'NonProg'
        idx = 0
        label = 0
        
    if folder == 'Not_Progressive_Rock/Top_Of_The_Pops':
        reName = 'NonProgTopPops-'
        label = 0
    
    filesNames = os.listdir('./Dataset/'+folder)
    for i in range(len(filesNames)):
        fileName = filesNames[i]
        print(i)
        print(fileName)
        audio_path = './Dataset/'+folder+'/'+fileName
        formalName = fileName.split('.')[-1]
        FilExt = fileName.split('.')[-1]
        if FilExt != 'mp3':
            flac_audio = AudioSegment.from_file('./Dataset/'+folder+'/'+fileName, FilExt)
            fileName = fileName.replace(fileName.split('.')[-1],'')+'mp3'
            audio_path = './FlatToMP3/'+folder+'/'+fileName
            flac_audio.export(audio_path, format="mp3")    
        print(fileName)
        saveName = reName+str(idx)
        totalDur = audioread.audio_open(audio_path).duration

        plt.cla()
        plt.clf()
        plt.close('all')
        plt.figure(1, figsize=(14, 5))
        x , sr = librosa.load(audio_path, sr=22050, offset=totalDur/2-30, duration=60.0) 
        #display Spectrogram
        X = librosa.stft(x, hop_length=256, n_fft=4096)
        Xdb = librosa.amplitude_to_db(abs(X), ref=np.max)
        print(Xdb.shape)
        if Xdb.shape[1] != 5168:
            continue
        

        #librosa.display.specshow(Xdb, hop_length=256, sr=sr, x_axis='time', y_axis='hz', cmap='gray_r') #, vmin=-50, vmax=50, 
        librosa.display.specshow(Xdb, hop_length=256, sr=sr, x_axis='time', y_axis='hz') #, vmin=-50, vmax=50, 
        cb=plt.colorbar(format="%+2.f dB")
        
        plt.savefig(saveFolder+saveName+'-withAix.png')

        plt.axis('off')
        cb.remove()
        plt.draw() #update plot
        plt.savefig(saveFolder+saveName+'.png')
        #plt.show()       
    
        ###Resize each img size into 200x200 for CNN training
        readImg1 = cv2.imread(saveFolder+saveName+'.png')
        resizeImg1 = cv2.resize(readImg1,(200,200))
        cv2.imwrite(saveFolder+saveName+'-Resize.png', resizeImg1)
        #########################################################
        
        ###Log img###############################################
        plt.cla()
        plt.clf()
        plt.close('all')
        plt.figure(2, figsize=(14, 5))
        librosa.display.specshow(Xdb, hop_length=256, sr=sr, x_axis='time', y_axis='log') #, vmin=-50, vmax=50,
        cb=plt.colorbar(format="%+2.f dB")
        
        plt.savefig(saveFolder+saveName+'-LogwithAix.png')

        plt.axis('off')
        cb.remove()
        plt.draw() #update plot
        plt.savefig(saveFolder+saveName+'-Log.png')
        #plt.show()       
    
        ###Resize each img size into 200x200 for CNN training
        readImg2 = cv2.imread(saveFolder+saveName+'-Log.png')
        resizeImg2 = cv2.resize(readImg2,(200,200))
        cv2.imwrite(saveFolder+saveName+'-LogResize.png', resizeImg2)
        ##############################################################
        ##############################################################
        
        saveArr.append(Xdb)
        labels.append(label)
        filesName.append(fileName)
        saveImgArr.append(resizeImg1)
        saveImgArrLog.append(resizeImg2)
        
        database['idx'].append(idx)
        database['ReName'].append(saveName)
        database['OriName'].append(fileName)
        database['Style'].append(style)
        database['Label'].append(label)
        database['StartDur (Sec)'].append(totalDur/2-30)
        database['EndDur (Sec)'].append(totalDur/2-30+60)
        database['Duration (Sec)'].append(totalDur)
        database['DbMax'].append(Xdb.max())
        database['DbMin'].append(Xdb.min())
        idx+=1

    #break
np.save('./ExtractDataset/DBHzarray.npy', saveArr)
np.save('./ExtractDataset/Imgages.npy', saveImgArr)
np.save('./ExtractDataset/LogImages.npy', saveImgArrLog) 
np.save('./ExtractDataset/Labels.npy', labels)
np.save('./ExtractDataset/FilesName.npy', filesName) 

DatabaseToPd = pd.DataFrame(data=database)
DatabaseToPd.to_excel('Database.xlsx', index=True)
# Out:
# 0
# -04- Knots.mp3
# -04- Knots.mp3
# (2049, 5168)
# 1
# 01 - '2112' (I. Overture, II. The Temples Of Syrinx, III. Discovery, IV. Presentation, V. Oracle_ The Dream, VI. Soliloquy, VII. Grand Finale).mp3
# 01 - '2112' (I. Overture, II. The Temples Of Syrinx, III. Discovery, IV. Presentation, V. Oracle_ The Dream, VI. Soliloquy, VII. Grand Finale).mp3
# (2049, 5168)
# 2
# 01 - Birds of Fire.mp3
# 01 - Birds of Fire.mp3
# (2049, 5168)
# 3
# 01 - Luminol.mp3
# 01 - Luminol.mp3
# (2049, 5168)
# 4
# 01 - Phaedra.flac
# 01 - Phaedra.mp3
# (2049, 5168)
# 5
# 01 - Roundabout.mp3
# 01 - Roundabout.mp3
# (2049, 5168)
# 6
# 01 - Songs From The Wood (2003 Digital Remaster).mp3
# 01 - Songs From The Wood (2003 Digital Remaster).mp3
# (2049, 5168)
# 7
# 01 A Change of Seasons_ I. The Crimson Sunrise _ II. Innocence _ III. Carpe Diem _ IV. The Darkest of Winters _ V. Another World _ VI. The Inevitable Summer _ VII. The Crimson Sunset.flac
# 01 A Change of Seasons_ I. The Crimson Sunrise _ II. Innocence _ III. Carpe Diem _ IV. The Darkest of Winters _ V. Another World _ VI. The Inevitable Summer _ VII. The Crimson Sunset.mp3
# (2049, 5168)
# 8
# 01 Close to the Edge I. The Solid Time of Change II. Total Mass Retain III.  I GetUp I Get Down IV. Seasons of Man).mp3
# 01 Close to the Edge I. The Solid Time of Change II. Total Mass Retain III.  I GetUp I Get Down IV. Seasons of Man).mp3
# (2049, 5168)
# 9
# 01 Jordrok.mp3
# 01 Jordrok.mp3
# (2049, 5168)
# 10
# 01 Meeting of the Spirits.mp3
# 01 Meeting of the Spirits.mp3
# (2049, 5168)
# 11
# 01 Peaches En Regalia.mp3
# 01 Peaches En Regalia.mp3
# (2049, 5168)
# 12
# 01 Script For A Jester's Tear.mp3
# 01 Script For A Jester's Tear.mp3
# (2049, 5168)
# 13
# 01 The Gates Of Delirium.mp3
# 01 The Gates Of Delirium.mp3
# (2049, 5168)
# 14
# 01-genesis-dancing_with_the_moonlit_knight.mp3
# 01-genesis-dancing_with_the_moonlit_knight.mp3
# (2049, 5168)
# 15
# 01-Hocus Pocus.mp3
# 01-Hocus Pocus.mp3
# (2049, 5168)
# 16
# 01-hymn_of_the_seventh_galaxy_320_lame_cbr.mp3
# 01-hymn_of_the_seventh_galaxy_320_lame_cbr.mp3
# (2049, 5168)
# 17
# 01. Folklore.mp3
# 01. Folklore.mp3
# (2049, 5168)
# 18
# 01. Hallogallo.mp3
# 01. Hallogallo.mp3
# (2049, 5168)
# 19
# 01. Hazard Profile Part One.mp3
# 01. Hazard Profile Part One.mp3
# (2049, 5168)
# 20
# 01. The Same River.mp3
# 01. The Same River.mp3
# (2049, 5168)
# 21
# 01.A passion play 1.mp3
# 01.A passion play 1.mp3
# (2049, 5168)
# 22
# 01_-_the_revealing_science_of_god_-_dance_of_the_dawn_320_lame_cbr.mp3
# 01_-_the_revealing_science_of_god_-_dance_of_the_dawn_320_lame_cbr.mp3
# (2049, 5168)
# 23
# 01_Genesis_The Musical Box.mp3
# 01_Genesis_The Musical Box.mp3
# (2049, 5168)
# 24
# 01_Genesis_Watcher of the Skies.mp3
# 01_Genesis_Watcher of the Skies.mp3
# (2049, 5168)
# 25
# 01_Shine On You Crazy Diamond I.mp3
# 01_Shine On You Crazy Diamond I.mp3
# (2049, 5168)
# 26
# 01_Yours Is No Disgrace.mp3
# 01_Yours Is No Disgrace.mp3
# (2049, 5168)
# 27
# 02 - Arbeit Macht Frei.mp3
# 02 - Arbeit Macht Frei.mp3
# (2049, 5168)
# 28
# 02 Can You Understand.mp3
# 02 Can You Understand.mp3
# (2049, 5168)
# 29
# 02 In a Silent Way...It's About that Time.mp3
# 02 In a Silent Way...It's About that Time.mp3
# (2049, 5168)
# 30
# 02. Bleed (live).mp3
# 02. Bleed (live).mp3
# (2049, 5168)
# 31
# 02_Dogs.mp3
# 02_Dogs.mp3
# (2049, 5168)
# 32
# 03 - Halleluwah.flac
# 03 - Halleluwah.mp3
# (2049, 5168)
# 33
# 03 A Plague of Lighthouse Keepers.mp3
# 03 A Plague of Lighthouse Keepers.mp3
# (2049, 5168)
# 34
# 03-genesis-firth_of_fifth.mp3
# 03-genesis-firth_of_fifth.mp3
# (2049, 5168)
# 35
# 03Uriah Heep - July Morning.mp3
# 03Uriah Heep - July Morning.mp3
# (2049, 5168)
# 36
# 03_Anesthetize.mp3
# 03_Anesthetize.mp3
# (2049, 5168)
# 37
# 03_Time.mp3
# 03_Time.mp3
# (2049, 5168)
# 38
# 03_YYZ_Rush_Moving_Pictures_Deluxe_Edition_2011.mp3
# 03_YYZ_Rush_Moving_Pictures_Deluxe_Edition_2011.mp3
# (2049, 5168)
# 39
# 04 Black Rose Immortal.mp3
# 04 Black Rose Immortal.mp3
# (2049, 5168)
# 40
# 04 The Sleepwalkers.mp3
# 04 The Sleepwalkers.mp3
# (2049, 5168)
# 41
# 04-Stranger In Your Soul_Resampled.mp3
# 04-Stranger In Your Soul_Resampled.mp3
# (2049, 5168)
# 42
# 04. Second Life Syndrome.mp3
# 04. Second Life Syndrome.mp3
# (2049, 5168)
# 43
# 04. The Czar I. Usurper - II. Escape - III. Martyr - IV. Spiral_khaos[].mp3
# 04. The Czar I. Usurper - II. Escape - III. Martyr - IV. Spiral_khaos[].mp3
# (2049, 5168)
# 44
# 04_La_Villa_Strangiato_Rush_Hemispheres_Deluxe_Edition.mp3
# 04_La_Villa_Strangiato_Rush_Hemispheres_Deluxe_Edition.mp3
# (2049, 5168)
# 45
# 05 - Starless.mp3
# 05 - Starless.mp3
# (2049, 5168)
# 46
# 05 - The Afternoon_ a) Forever Afternoon (Tuesday_) · b) (Evening) Time to Get Away.mp3
# 05 - The Afternoon_ a) Forever Afternoon (Tuesday_) · b) (Evening) Time to Get Away.mp3
# (2049, 5168)
# 47
# 05 - Vivaldi.mp3
# 05 - Vivaldi.mp3
# (2049, 5168)
# 48
# 05-Nine Feet Underground.mp3
# 05-Nine Feet Underground.mp3
# (2049, 5168)
# 49
# 05-Phallus Dei.mp3
# 05-Phallus Dei.mp3
# (2049, 5168)
# 50
# 05. When the Water Breaks.mp3
# 05. When the Water Breaks.mp3
# (2049, 5168)
# 51
# 05_Arriving Somewhere but Not Here.mp3
# 05_Arriving Somewhere but Not Here.mp3
# (2049, 5168)
# 52
# 05_Schism.mp3
# 05_Schism.mp3
# (2049, 5168)
# 53
# 06 - Echoes.mp3
# 06 - Echoes.mp3
# (2049, 5168)
# 54
# 06 - Scene Four  Beyond This Life.mp3
# 06 - Scene Four  Beyond This Life.mp3
# (2049, 5168)
# 55
# 06 Mekanik Kommandoh.mp3
# 06 Mekanik Kommandoh.mp3
# (2049, 5168)
# 56
# 06-In a glass house.mp3
# 06-In a glass house.mp3
# (2049, 5168)
# 57
# 06-king_crimson-larks_tounges_in_aspic_(part_ii).mp3
# 06-king_crimson-larks_tounges_in_aspic_(part_ii).mp3
# (2049, 5168)
# 58
# 06. Milliontown.mp3
# 06. Milliontown.mp3
# (2049, 5168)
# 59
# 06_Genesis_Supper's Ready.mp3
# 06_Genesis_Supper's Ready.mp3
# (2049, 5168)
# 60
# 07 - Fool's Overture.mp3
# 07 - Fool's Overture.mp3
# (2049, 5168)
# 61
# 07 - The Night_ Nights in White Satin.mp3
# 07 - The Night_ Nights in White Satin.mp3
# (2049, 5168)
# 62
# 07 - Zartlicher Abschied.mp3
# 07 - Zartlicher Abschied.mp3
# (2049, 5168)
# 63
# 07 A Louse Is Not A Home.mp3
# 07 A Louse Is Not A Home.mp3
# (2049, 5168)
# 64
# 08 - Kingdom Of Dreams.mp3
# 08 - Kingdom Of Dreams.mp3
# (2049, 5168)
# 65
# 08 - Lady Fantasy.mp3
# 08 - Lady Fantasy.mp3
# (2049, 5168)
# 66
# 08 - Octavarium.mp3
# 08 - Octavarium.mp3
# (2049, 5168)
# 67
# 08 - The Divine Wings Of Tragedy.mp3
# 08 - The Divine Wings Of Tragedy.mp3
# (2049, 5168)
# 68
# 08 - White Walls.mp3
# 08 - White Walls.mp3
# (2049, 5168)
# 69
# 08-This Strange Engine.mp3
# 08-This Strange Engine.mp3
# (2049, 5168)
# 70
# 08. Guardian.mp3
# 08. Guardian.mp3
# (2049, 5168)
# 71
# 08_-_opeth_-_blackwater park_-_blackwater park.mp3
# 08_-_opeth_-_blackwater park_-_blackwater park.mp3
# (2049, 5168)
# 72
# 09 - Ancestral.mp3
# 09 - Ancestral.mp3
# (2049, 5168)
# 73
# 09 - Headlong Flight.mp3
# 09 - Headlong Flight.mp3
# (2049, 5168)
# 74
# 09 Heart Of The Sunrise.mp3
# 09 Heart Of The Sunrise.mp3
# (2049, 5168)
# 75
# 09. Bo Hansson - Rohans Horn - Slaget vid Pelennors slatter.mp3
# 09. Bo Hansson - Rohans Horn - Slaget vid Pelennors slatter.mp3
# (2049, 5168)
# 76
# 101 21st Century Schizoid Man.mp3
# 101 21st Century Schizoid Man.mp3
# (2049, 5168)
# 77
# 101-elp-tarkus.mp3
# 101-elp-tarkus.mp3
# (2049, 5168)
# 78
# 103 Epitaph.mp3
# 103 Epitaph.mp3
# (2049, 5168)
# 79
# 103 Moon In June.mp3
# 103 Moon In June.mp3
# (2049, 5168)
# 80
# 105-emerson_lake_and_palmer-karn_evil_9_1st_impression_(part_1).mp3
# 105-emerson_lake_and_palmer-karn_evil_9_1st_impression_(part_1).mp3
# (2049, 5168)
# 81
# 11 Bohemian Rhapsody.mp3
# 11 Bohemian Rhapsody.mp3
# (2049, 5168)
# 82
# 12-animals_as_leaders-song_of_solomon.mp3
# 12-animals_as_leaders-song_of_solomon.mp3
# (2049, 5168)
# 83
# 13 - A Day in the Life.mp3
# 13 - A Day in the Life.mp3
# (2049, 5168)
# 84
# 13 Aenema.mp3
# 13 Aenema.mp3
# (2049, 5168)
# 85
# 205 The Court Of The Crimson King.mp3
# 205 The Court Of The Crimson King.mp3
# (2049, 5168)
# 86
# 4-Song Of Scheherazade.mp3
# 4-Song Of Scheherazade.mp3
# (2049, 5168)
# 87
# 5  The architect.mp3
# 5  The architect.mp3
# (2049, 5168)
# 88
# Appena un poco.mp3
# Appena un poco.mp3
# (2049, 5168)
# 89
# Big Big Train - English Electric (Part Two) - 01 - East Coast Racer.mp3
# Big Big Train - English Electric (Part Two) - 01 - East Coast Racer.mp3
# (2049, 5168)
# 90
# Frances the Mute-The Mars Volta-05-Cassandra Geminni 1.mp3
# Frances the Mute-The Mars Volta-05-Cassandra Geminni 1.mp3
# (2049, 5168)
# 91
# Kansas - 08 Magnum Opus a)Father Padilla Meets The Perfect Gnat b)Howling At The Moon c)Man Overboard d)Industry On Parade e)Release The Be.mp3
# Kansas - 08 Magnum Opus a)Father Padilla Meets The Perfect Gnat b)Howling At The Moon c)Man Overboard d)Industry On Parade e)Release The Be.mp3
# (2049, 5168)
# 92
# Kraftwerk - 01 - Autobahn.mp3
# Kraftwerk - 01 - Autobahn.mp3
# (2049, 5168)
# 93
# L'evoluzione.mp3
# L'evoluzione.mp3
# (2049, 5168)
# 94
# MIKE OLDFIELD - Part One (Tubular Bells I).mp3
# MIKE OLDFIELD - Part One (Tubular Bells I).mp3
# (2049, 5168)
# 95
# Pain of Salvation - The Perfect Element I - 02. In the Flesh.mp3
# Pain of Salvation - The Perfect Element I - 02. In the Flesh.mp3
# (2049, 5168)
# 96
# The Flower Kings - 1997 Stardust We Are CD2 - 11 - Stardust We Are.mp3
# The Flower Kings - 1997 Stardust We Are CD2 - 11 - Stardust We Are.mp3
# (2049, 5168)
# 97
# Thick As A Brick.mp3
# Thick As A Brick.mp3
# (2049, 5168)
# 0
# 01 - Autumn Lords.mp3
# 01 - Autumn Lords.mp3
# (2049, 5168)
# 1
# 01 - Big Chief.mp3
# 01 - Big Chief.mp3
# (2049, 5168)
# 2
# 01 - End Titles from Blade Runner.mp3
# 01 - End Titles from Blade Runner.mp3
# (2049, 5168)
# 3
# 01 - My Spirit Will Go On.mp3
# 01 - My Spirit Will Go On.mp3
# (2049, 5168)
# 4
# 01 - Pulcinella, 1st scene_ Ouverture.mp3
# 01 - Pulcinella, 1st scene_ Ouverture.mp3
# (2049, 5168)
# 5
# 01 - Tiempo Al Tiempo.mp3
# 01 - Tiempo Al Tiempo.mp3
# (2049, 5168)
# 6
# 01-Light - Look At Your Sun.mp3
# 01-Light - Look At Your Sun.mp3
# (2049, 5168)
# 7
# 01. Painkiller.mp3
# 01. Painkiller.mp3
# (2049, 5168)
# 8
# 01.ArmenMiran-PreciousStory.mp3
# 01.ArmenMiran-PreciousStory.mp3
# (2049, 5168)
# 9
# 01_Surfing with the Alien.mp3
# 01_Surfing with the Alien.mp3
# (2049, 5168)
# 10
# 02 - Adagio in C Minor.mp3
# 02 - Adagio in C Minor.mp3
# (2049, 5168)
# 11
# 02 - Joie De Vivre.mp3
# 02 - Joie De Vivre.mp3
# (2049, 5168)
# 12
# 02 - Petrichrist.mp3
# 02 - Petrichrist.mp3
# (2049, 5168)
# 13
# 02 - Someone In The Crowd.mp3
# 02 - Someone In The Crowd.mp3
# (2049, 5168)
# 14
# 02 - Violin Concerto in D Major_ Adagio.mp3
# 02 - Violin Concerto in D Major_ Adagio.mp3
# (2049, 5168)
# 15
# 02 Aja.mp3
# 02 Aja.mp3
# (2049, 5168)
# 16
# 03 - Angel of Music.mp3
# 03 - Angel of Music.mp3
# (2049, 5168)
# 17
# 03 - Bayaty.mp3
# 03 - Bayaty.mp3
# (2049, 5168)
# 18
# 03 - The national anthem.mp3
# 03 - The national anthem.mp3
# (2049, 5168)
# 19
# 03 Midnight At The Bazaar.mp3
# 03 Midnight At The Bazaar.mp3
# (2049, 5168)
# 20
# 03-oneohtrix_point_never-betrayed_in_the_octagon-kouala.mp3
# 03-oneohtrix_point_never-betrayed_in_the_octagon-kouala.mp3
# (2049, 5168)
# 21
# 03. Ten-Day Interval.mp3
# 03. Ten-Day Interval.mp3
# (2049, 5168)
# 22
# 03_Losfer Words (Big 'Orra).mp3
# 03_Losfer Words (Big 'Orra).mp3
# (2049, 5168)
# 23
# 04 - Ayasofya.mp3
# 04 - Ayasofya.mp3
# (2049, 5168)
# 24
# 04 - Big Shot.mp3
# 04 - Big Shot.mp3
# (2049, 5168)
# 25
# 04 - Condor Pasa.mp3
# 04 - Condor Pasa.mp3
# (2049, 5168)
# 26
# 04 - Devil's Advocate _ Bambodansarna.mp3
# 04 - Devil's Advocate _ Bambodansarna.mp3
# (2049, 5168)
# 27
# 04 - El corrido de Alfonso.mp3
# 04 - El corrido de Alfonso.mp3
# (2049, 5168)
# 28
# 04 - Out Of The Blue.mp3
# 04 - Out Of The Blue.mp3
# (2049, 5168)
# 29
# 04 - Piano Concerto No. 2 - 1. Allegro.mp3
# 04 - Piano Concerto No. 2 - 1. Allegro.mp3
# (2049, 5168)
# 30
# 04 Dounounia.mp3
# 04 Dounounia.mp3
# (2049, 5168)
# 31
# 04-deacon_blues_320_lame_cbr.mp3
# 04-deacon_blues_320_lame_cbr.mp3
# (2049, 5168)
# 32
# 04-Invisible Limits.mp3
# 04-Invisible Limits.mp3
# (2049, 5168)
# 33
# 04-The Rip.mp3
# 04-The Rip.mp3
# (2049, 5168)
# 34
# 05 - Go to the West - Meeting in Menggu Tents - Be Together - Sister Liu.mp3
# 05 - Go to the West - Meeting in Menggu Tents - Be Together - Sister Liu.mp3
# (2049, 5168)
# 35
# 05 - Moonwind.mp3
# 05 - Moonwind.mp3
# (2049, 5168)
# 36
# 05-Tjolky [Тьолки].mp3
# 05-Tjolky [Тьолки].mp3
# (2049, 5168)
# 37
# 05. Violin Concerto in E minor op.64 - I Allegro molto appassionato.mp3
# 05. Violin Concerto in E minor op.64 - I Allegro molto appassionato.mp3
# (2049, 5168)
# 38
# 06 - Give It Up.mp3
# 06 - Give It Up.mp3
# (2049, 5168)
# 39
# 06 - Sigur Rós - Sæglópur.mp3
# 06 - Sigur Rós - Sæglópur.mp3
# (2049, 5168)
# 40
# 06 Savana Dance.mp3
# 06 Savana Dance.mp3
# (2049, 5168)
# 41
# 06. In A Gadda Da Vida.mp3
# 06. In A Gadda Da Vida.mp3
# (2049, 5168)
# 42
# 07_Summoning Of The Muse.mp3
# 07_Summoning Of The Muse.mp3
# (2049, 5168)
# 43
# 08 - Asmarina (My Asmara).mp3
# 08 - Asmarina (My Asmara).mp3
# (2049, 5168)
# 44
# 08 - Tsinandali Choir - Orovela.mp3
# 08 - Tsinandali Choir - Orovela.mp3
# (2049, 5168)
# 45
# 08 - Xoomij.mp3
# 08 - Xoomij.mp3
# (2049, 5168)
# 46
# 08 I Could Have Danced All Night.mp3
# 08 I Could Have Danced All Night.mp3
# (2049, 5168)
# 47
# 08 Listen.mp3
# 08 Listen.mp3
# (2049, 5168)
# 48
# 08-love_to_love_320_lame_cbr.mp3
# 08-love_to_love_320_lame_cbr.mp3
# (2049, 5168)
# 49
# 09. Tel Aviv.mp3
# 09. Tel Aviv.mp3
# (2049, 5168)
# 50
# 1-01 Eruption.mp3
# 1-01 Eruption.mp3
# (2049, 5168)
# 51
# 11 - Hello Earth.mp3
# 11 - Hello Earth.mp3
# (2049, 5168)
# 52
# 13 - Al Hahla Al ’Ali.mp3
# 13 - Al Hahla Al ’Ali.mp3
# (2049, 5168)
# 53
# 13 - So Long, Farewell.mp3
# 13 - So Long, Farewell.mp3
# (2049, 5168)
# 54
# 13 Metin Arolat - Elveda.mp3
# 13 Metin Arolat - Elveda.mp3
# (2049, 5168)
# 55
# 16 - Madhuban Mein Radhika Nache Re (Kohinoor 1960).mp3
# 16 - Madhuban Mein Radhika Nache Re (Kohinoor 1960).mp3
# (2049, 5168)
# 56
# 16 - Navras.mp3
# 16 - Navras.mp3
# (2049, 5168)
# 57
# 3. My Beautiful Dark Twisted Fantasy - POWER.mp3
# 3. My Beautiful Dark Twisted Fantasy - POWER.mp3
# (2049, 5168)
# 58
# Ali Farka Toure with Ry Cooder - Talking Timbuktu - 10 - Diaraby.mp3
# Ali Farka Toure with Ry Cooder - Talking Timbuktu - 10 - Diaraby.mp3
# (2049, 5168)
# 59
# Anu_Orta_Veniya.mp3
# Anu_Orta_Veniya.mp3
# (2049, 5168)
# 60
# Aphex Twin - Avril 14th.mp3
# Aphex Twin - Avril 14th.mp3
# (2049, 5168)
# 61
# C-Pop_Hits_1.mp3
# C-Pop_Hits_1.mp3
# (2049, 5168)
# 62
# Chinna Chinna Aasai - ROJA.mp3
# Chinna Chinna Aasai - ROJA.mp3
# (2049, 5168)
# 63
# Hallelujah_Kate_McKinnon.mp3
# Hallelujah_Kate_McKinnon.mp3
# (2049, 5168)
# 64
# K-Pop_1.mp3
# K-Pop_1.mp3
# (2049, 5168)
# 65
# Khalil_Fong_Love_in_this_world.mp3
# Khalil_Fong_Love_in_this_world.mp3
# (2049, 5168)
# 66
# Nena ‎- 99 Luftballons.mp3
# Nena ‎- 99 Luftballons.mp3
# (2049, 5168)
# 67
# Paul Gilbert - Technical Difficulties (Racer X).mp3
# Paul Gilbert - Technical Difficulties (Racer X).mp3
# (2049, 5168)
# 68
# rasme-asheghi.mp3
# rasme-asheghi.mp3
# (2049, 5168)
# 69
# Russ Conway - Pepe.mp3
# Russ Conway - Pepe.mp3
# (2049, 5168)
# 70
# Russian_2.mp3
# Russian_2.mp3
# (2049, 5168)
# 71
# Salif Keita - Cono.mp3
# Salif Keita - Cono.mp3
# (2049, 5168)
# 72
# Serge_Prokofiev_1.mp3
# Serge_Prokofiev_1.mp3
# (2049, 5168)
# 73
# Symphony_40_G_Minor.mp3
# Symphony_40_G_Minor.mp3
# (2049, 5168)
# 0
# 1939_Judy_Garland_Somewhere_Over_The_Rainbow.mp3
# 1939_Judy_Garland_Somewhere_Over_The_Rainbow.mp3
# (2049, 5168)
# 1
# 1940_Tommy_Dorsey_I'll_Never_Smile_Again.mp3
# 1940_Tommy_Dorsey_I'll_Never_Smile_Again.mp3
# (2049, 5168)
# 2
# 1941_Glenn_Miller_Chatanooga_Choo_Choo.mp3
# 1941_Glenn_Miller_Chatanooga_Choo_Choo.mp3
# (2049, 5168)
# 3
# 1942_Kay_Kyser_Praise_the_Lord_and_Pass_the_Ammunition.mp3
# 1942_Kay_Kyser_Praise_the_Lord_and_Pass_the_Ammunition.mp3
# (2049, 5168)
# 4
# 1943_Duke_Ellington_In_A_Sentimental.mp3
# 1943_Duke_Ellington_In_A_Sentimental.mp3
# (2049, 5168)
# 5
# 1944_Les_Brown_Twilight_Time.mp3
# 1944_Les_Brown_Twilight_Time.mp3
# (2049, 5168)
# 6
# 1945_Harry_James_and_Kitty_Kallen_It's_Been_A_Long_Long_Time.mp3
# 1945_Harry_James_and_Kitty_Kallen_It's_Been_A_Long_Long_Time.mp3
# (2049, 5168)
# 7
# 1946_Perry_Como_Prisoner_of_Love.mp3
# 1946_Perry_Como_Prisoner_of_Love.mp3
# (2049, 5168)
# 8
# 1947_Francis_Craig_and_His_Orchestra_Near_You.mp3
# 1947_Francis_Craig_and_His_Orchestra_Near_You.mp3
# (2049, 5168)
# 9
# 1948_Peggy_Lee_Manana.mp3
# 1948_Peggy_Lee_Manana.mp3
# (2049, 5168)
# 10
# 1949_Vaughan_Monroe_Riders_In_The_Sky.mp3
# 1949_Vaughan_Monroe_Riders_In_The_Sky.mp3
# (2049, 5168)
# 11
# 1950_Nat_King_Cole_Mona_Lisa.mp3
# 1950_Nat_King_Cole_Mona_Lisa.mp3
# (2049, 5168)
# 12
# 1951_Tony_Bennett_Because_Of_You.mp3
# 1951_Tony_Bennett_Because_Of_You.mp3
# (2049, 5168)
# 13
# 1952_Vera_Lynn_Auf_Wiederseh`n_Sweetheart.mp3
# 1952_Vera_Lynn_Auf_Wiederseh`n_Sweetheart.mp3
# (2049, 5168)
# 14
# 1953_Les_Paul_And_Mary_Ford_Vaya_Con_Dios.mp3
# 1953_Les_Paul_And_Mary_Ford_Vaya_Con_Dios.mp3
# (2049, 5168)
# 15
# 1954_Rosemary_Clooney_Hey_There.mp3
# 1954_Rosemary_Clooney_Hey_There.mp3
# (2049, 5168)
# 16
# 1955_Bill_Haley_And_His_Comets_Rock_Around_The_Clock.mp3
# 1955_Bill_Haley_And_His_Comets_Rock_Around_The_Clock.mp3
# (2049, 5168)
# 17
# 1956_Elvis_Presley_Heartbreak_Hotel.mp3
# 1956_Elvis_Presley_Heartbreak_Hotel.mp3
# (2049, 5168)
# 18
# 1957_Harry_Belafonte_Banana_Boat_Song.mp3
# 1957_Harry_Belafonte_Banana_Boat_Song.mp3
# (2049, 5168)
# 19
# 1958_The_Champs_Tequila.mp3
# 1958_The_Champs_Tequila.mp3
# (2049, 5168)
# 20
# 1959_Johnny_Horton_The_Battle_Of_New_Orleans.mp3
# 1959_Johnny_Horton_The_Battle_Of_New_Orleans.mp3
# (2049, 5168)
# 21
# 1960_Bryan_Hyland_Itsy_Bitsy.mp3
# 1960_Bryan_Hyland_Itsy_Bitsy.mp3
# (2049, 5168)
# 22
# 1961_Lawrence_Welk_Calcutta.mp3
# 1961_Lawrence_Welk_Calcutta.mp3
# (2049, 5168)
# 23
# 1962_Ray_Charles_I_Can't_Stop_Loving_You.mp3
# 1962_Ray_Charles_I_Can't_Stop_Loving_You.mp3
# (2049, 5168)
# 24
# 1963_Peter_Paul_And_Mary_Puff_The_Magic_Dragon.mp3
# 1963_Peter_Paul_And_Mary_Puff_The_Magic_Dragon.mp3
# (2049, 5168)
# 25
# 1964_The_Beatles_I_Want_To_Hold_Your_Hand.mp3
# 1964_The_Beatles_I_Want_To_Hold_Your_Hand.mp3
# (2049, 5168)
# 26
# 1965_Beach_Boys_California_Girls.mp3
# 1965_Beach_Boys_California_Girls.mp3
# (2049, 5168)
# 27
# 1966_The_Rolling_Stones_Paint_It_Black.mp3
# 1966_The_Rolling_Stones_Paint_It_Black.mp3
# (2049, 5168)
# 28
# 1967_The_Doors_Light_My_Fire.mp3
# 1967_The_Doors_Light_My_Fire.mp3
# (2049, 5168)
# 29
# 1968_Steppenwolf_Born_To_Be_Wild.mp3
# 1968_Steppenwolf_Born_To_Be_Wild.mp3
# (2049, 5168)
# 30
# 1969_Neil_Diamond_Sweet_Caroline.mp3
# 1969_Neil_Diamond_Sweet_Caroline.mp3
# (2049, 5168)
# 31
# 1970_Simon_and_Garfunkel_Bridge_Over_Troubled_Water.mp3
# 1970_Simon_and_Garfunkel_Bridge_Over_Troubled_Water.mp3
# (2049, 5168)
# 32
# 1971_Rod_Stewart_Maggie_May.mp3
# 1971_Rod_Stewart_Maggie_May.mp3
# (2049, 5168)
# 33
# 1972_Don_McLean_American_Pie.mp3
# 1972_Don_McLean_American_Pie.mp3
# (2049, 5168)
# 34
# 1973_Diana_Ross_Touch_Me_In_The_Morning.mp3
# 1973_Diana_Ross_Touch_Me_In_The_Morning.mp3
# (2049, 5168)
# 35
# 1974_Jackson_5_Dancing_Machine.mp3
# 1974_Jackson_5_Dancing_Machine.mp3
# (2049, 5168)
# 36
# 1975_America_Sister_Golden_Hair.mp3
# 1975_America_Sister_Golden_Hair.mp3
# (2049, 5168)
# 37
# 1976_Eagles_Hotel_California.mp3
# 1976_Eagles_Hotel_California.mp3
# (2049, 5168)
# 38
# 1977_ABBA_Dancing_Queen.mp3
# 1977_ABBA_Dancing_Queen.mp3
# (2049, 5168)
# 39
# 1978_Bee_Gees_Night_Fever.mp3
# 1978_Bee_Gees_Night_Fever.mp3
# (2049, 5168)
# 40
# 1979_The_Knack_My_Sharona.mp3
# 1979_The_Knack_My_Sharona.mp3
# (2049, 3923)
# 41
# 1980_Pink_Floyd_Another_Brick_In_The_Wall_Part_II.mp3
# 1980_Pink_Floyd_Another_Brick_In_The_Wall_Part_II.mp3
# (2049, 5168)
# 42
# 1981_Kim_Carnes_Bette_Davis_Eyes.mp3
# 1981_Kim_Carnes_Bette_Davis_Eyes.mp3
# (2049, 5168)
# 43
# 1982_Foreigner_Waiting_For_A_Girl_Like_You.mp3
# 1982_Foreigner_Waiting_For_A_Girl_Like_You.mp3
# (2049, 5168)
# 44
# 1983_Police_Every_Breath_You_Take.mp3
# 1983_Police_Every_Breath_You_Take.mp3
# (2049, 5168)
# 45
# 1984_Prince_When_Doves_Cry.mp3
# 1984_Prince_When_Doves_Cry.mp3
# (2049, 5168)
# 46
# 1985_Wham_Careless_Whisper.mp3
# 1985_Wham_Careless_Whisper.mp3
# (2049, 5168)
# 47
# 1986_Mr._Mister_Broken_Wings.mp3
# 1986_Mr._Mister_Broken_Wings.mp3
# (2049, 5168)
# 48
# 1987_Heart_Alone.mp3
# 1987_Heart_Alone.mp3
# (2049, 5168)
# 49
# 1988_INXS_Need_You_Tonight.mp3
# 1988_INXS_Need_You_Tonight.mp3
# (2049, 5168)
# 50
# 1989_Milli_Vanilli_Girl_You_Know_It's_True.mp3
# 1989_Milli_Vanilli_Girl_You_Know_It's_True.mp3
# (2049, 5168)
# 51
# 1990_Michael_Bolton_How_Am_I_Supposed_To_Live_Without_You.mp3
# 1990_Michael_Bolton_How_Am_I_Supposed_To_Live_Without_You.mp3
# (2049, 5168)
# 52
# 1991_Mariah_Carey_Someday.mp3
# 1991_Mariah_Carey_Someday.mp3
# (2049, 5168)
# 53
# 1992_Nirvana_Smells_Like_Teen_Spirit.mp3
# 1992_Nirvana_Smells_Like_Teen_Spirit.mp3
# (2049, 5168)
# 54
# 1993_Snap_Rhythm_Is_A_Dancer.mp3
# 1993_Snap_Rhythm_Is_A_Dancer.mp3
# (2049, 5168)
# 55
# 1994_Ace_Of_Base_All_That_She_Wants.mp3
# 1994_Ace_Of_Base_All_That_She_Wants.mp3
# (2049, 5168)
# 56
# 1995_Hootie_And_The_Blowfish_Hold_My_Hand.mp3
# 1995_Hootie_And_The_Blowfish_Hold_My_Hand.mp3
# (2049, 5168)
# 57
# 1996_Alanis_Morissette_Ironic.mp3
# 1996_Alanis_Morissette_Ironic.mp3
# (2049, 5168)
# 58
# 1997_The_Verve_Bittersweet_Symphony.mp3
# 1997_The_Verve_Bittersweet_Symphony.mp3
# (2049, 5168)
# 59
# 1998_Celine_Dion_My_Heart_Will_Go_On.mp3
# 1998_Celine_Dion_My_Heart_Will_Go_On.mp3
# (2049, 5168)
# 60
# 1999_Britney_Spears_...Baby_One_More_Time.mp3
# 1999_Britney_Spears_...Baby_One_More_Time.mp3
# (2049, 5168)
# 61
# 2000_Sting_Desert_Rose.mp3
# 2000_Sting_Desert_Rose.mp3
# (2049, 5168)
# 62
# 2001_Alan_Jackson_Where_Were_You.mp3
# 2001_Alan_Jackson_Where_Were_You.mp3
# (2049, 5168)
# 63
# 2001_Train_Drops_Of_Jupiter.mp3
# 2001_Train_Drops_Of_Jupiter.mp3
# (2049, 3191)
# 64
# 2002_Linkin_Park_In_The_End.mp3
# 2002_Linkin_Park_In_The_End.mp3
# (2049, 5168)
# 65
# 2003_Evanescence_Bring_Me_To_Life.mp3
# 2003_Evanescence_Bring_Me_To_Life.mp3
# (2049, 5168)
# 66
# 2004_Usher_Yeah.mp3
# 2004_Usher_Yeah.mp3
# (2049, 5168)
# 67
# 2005_Kelly_Clarkson_Since_U_Been_Gone.mp3
# 2005_Kelly_Clarkson_Since_U_Been_Gone.mp3
# (2049, 5168)
# 68
# 2006_Kanye_West_Gold_Digger.mp3
# 2006_Kanye_West_Gold_Digger.mp3
# (2049, 5168)
# 69
# 2007_Fergie_Big_Girls_Don't_Cry.mp3
# 2007_Fergie_Big_Girls_Don't_Cry.mp3
# (2049, 5168)
# 70
# 2008_Alicia_Keys_No_One.mp3
# 2008_Alicia_Keys_No_One.mp3
# (2049, 5168)
# 71
# 2009_Beyonce_Single_Ladies_Put_A_Ring_On_It.mp3
# 2009_Beyonce_Single_Ladies_Put_A_Ring_On_It.mp3
# (2049, 5168)
# 72
# 2010_Lady_Gaga_Telephone.mp3
# 2010_Lady_Gaga_Telephone.mp3
# (2049, 5168)
# 73
# 2011_Adele_Rolling_In_The_Deep.mp3
# 2011_Adele_Rolling_In_The_Deep.mp3
# (2049, 5168)
# 74
# 2012_Taylor_Swift_We_Are_Never_Getting_Back_Together.mp3
# 2012_Taylor_Swift_We_Are_Never_Getting_Back_Together.mp3
# (2049, 5168)
# 75
# 2013_Bruno_Mars_Locked_Out_Of_Heaven.mp3
# 2013_Bruno_Mars_Locked_Out_Of_Heaven.mp3
# (2049, 5168)
# 76
# 2014_Katy_Perry_Roar.mp3
# 2014_Katy_Perry_Roar.mp3
# (2049, 5168)
# 77
# 2015_Rihanna_FourFiveSeconds.mp3
# 2015_Rihanna_FourFiveSeconds.mp3
# (2049, 5168)
# 78
# 2016_Twenty_One_Pilots_Stressed_Out.mp3
# 2016_Twenty_One_Pilots_Stressed_Out.mp3
# (2049, 5168)
# 79
# 2017_Migos_Bad_&_Boujee.mp3
# 2017_Migos_Bad_&_Boujee.mp3
# (2049, 5168)
# 80
# 2018_Drake_God's_Plan.mp3
# 2018_Drake_God's_Plan.mp3
# (2049, 5168)
# 81
# 2019_Ariana_Grande_Thank_U,_Next.mp3
# 2019_Ariana_Grande_Thank_U,_Next.mp3
# (2049, 5168)
# 82
# 2020_BTS_Dynamite.m4a
# 2020_BTS_Dynamite.mp3
# (2049, 5168)
